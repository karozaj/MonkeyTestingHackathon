# %%
import pandas as pd
df = pd.read_csv('event_data.csv')

# %%
df
# Out:
#                                title  \
# 0           Pokémon TCG League Night
# 1       Pokémon TCG Trade & Play Day
# 2         Pokémon Theme Deck Battles
# 3                MTG Modern Showdown
# 4             Casual Commander Night
# 5                  MTG Pauper League
# 6               Lorcana Launch Party
# 7               Lorcana Casual Night
# 8       Lorcana Storytelling Evening
# 9         Yu-Gi-Oh! Local Tournament
# 10            Yu-Gi-Oh! Casual Duels
# 11              Yu-Gi-Oh! Rookie Day
# 12             Riftbound Arena Night
# 13         Riftbound Ranked Showdown
# 14          Riftbound Beginner event
# 15        One Piece TCG League Night
# 16          One Piece TCG Tournament
# 17           One Piece Casual Sunday
# 18            Flesh and Blood Armory
# 19          Flesh and Blood Skirmish
# 20     Flesh and Blood Casual Meetup
# 21      Star Wars Unlimited Premiere
# 22  Star Wars Unlimited League Night
# 23     Star Wars Unlimited Draft Day
# ...

# %%
df_1 = pd.read_csv('user_data.csv')
df_1
# Out:
#     user_id           username  location  \
# 0   usr_001         cardmaster  Warszawa
# 1   usr_002            pokefan    Krakow
# 2   usr_003       casualplayer    Gdansk
# 3   usr_004     commander_king    Poznan
# 4   usr_005     junior_trainer  Warszawa
# 5   usr_006       draft_addict   Wroclaw
# 6   usr_007     league_grinder      Lodz
# 7   usr_008        art_sleeves    Krakow
# 8   usr_009          newbie123  Warszawa
# 9   usr_010   mtg_standard_fan     Sopot
# 10  usr_011       family_gamer  Katowice
# 11  usr_012     collector_only    Lublin
# 12  usr_013            yu_hero  Warszawa
# 13  usr_014  late_night_player  Szczecin
# 14  usr_015     workshop_lover    Gdansk
# 15  usr_016    competitive_pro  Warszawa
# 16  usr_017     local_champion    Poznan
# 17  usr_018       social_gamer    Krakow
# 18  usr_019        deckbuilder   Wroclaw
# 19  usr_020      one_piece_fan  Warszawa
# 20  usr_021     yugioh_duelist    Krakow
# 21  usr_022      lorcana_lover    Gdansk
#
# ...
